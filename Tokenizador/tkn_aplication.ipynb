# %%
import tkn_functions as tknF
import json

# %%
# Abre o arquivo JSON e carrega o conteúdo
with open("corpus/248.json", "r") as arquivo:
    dados = json.load(arquivo)

# pega o texto do JSON
texto = dados["text"]

# %%
merge_script, id_adj_list, vocab = tknF.train(texto, 500)

# %%
encoded_txt = tknF.encode(texto, merge_script, id_adj_list)
encoded_txt
# Out:
# [65,
#  32,
#  73,
#  100,
#  101,
#  105,
#  258,
#  80,
#  101,
#  114,
#  105,
#  103,
#  111,
#  115,
#  258,
#  100,
#  256,
#  68,
#  97,
#  114,
#  119,
#  105,
#  110,
#  32,
#  40,
#  101,
#  109,
#  32,
#  80,
#  111,
#  114,
#  116,
#  117,
#  103,
#  97,
#  108,
#  41,
#  32,
#  111,
#  117,
#  32,
#  65,
#  32,
#  80,
#  101,
#  114,
#  105,
#  103,
#  111,
#  115,
#  258,
#  73,
#  100,
#  101,
#  105,
#  258,
#  100,
#  256,
#  68,
#  97,
#  114,
#  119,
#  105,
#  110,
#  32,
#  40,
#  110,
#  257,
#  66,
#  114,
#  97,
#  115,
#  105,
#  108,
#  41,
#  44,
#  32,
#  68,
#  97,
#  114,
#  119,
#  105,
#  110,
#  39,
#  115,
#  32,
#  68,
#  97,
#  110,
#  103,
#  101,
#  114,
#  111,
#  117,
#  115,
#  32,
#  73,
#  100,
#  101,
#  258,
#  110,
#  257,
#  111,
#  114,
#  105,
#  103,
#  105,
#  110,
#  97,
#  108,
#  32,
#  101,
#  109,
#  32,
#  105,
#  110,
#  103,
#  108,
#  195,
#  259,
#  170,
#  115,
#  44,
#  32,
#  195,
#  259,
#  169,
#  32,
#  117,
#  109,
#  32,
#  108,
#  105,
#  118,
#  114,
#  257,
#  100,
#  258,
#  97,
#  117,
#  116,
#  111,
#  114,
#  105,
#  258,
#  100,
#  256,
#  68,
#  97,
#  110,
#  105,
#  101,
#  108,
#  32,
#  67,
#  46,
#  32,
#  68,
#  101,
#  110,
#  110,
#  101,
#  116,
#  116,
#  32,
#  40,
#  49,
#  57,
#  57,
#  53,
#  41,
#  32,
#  113,
#  117,
#  256,
#  101,
#  120,
#  112,
#  108,
#  111,
#  114,
#  258,
#  111,
#  115,
#  32,
#  101,
#  102,
#  101,
#  105,
#  116,
#  111,
#  115,
#  32,
#  113,
#  117,
#  256,
#  258,
#  116,
#  101,
#  111,
#  114,
#  105,
#  258,
#  100,
#  258,
#  101,
#  118,
#  111,
#  108,
#  117,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  257,
#  100,
#  256,
#  67,
#  104,
#  97,
#  114,
#  108,
#  101,
#  115,
#  32,
#  68,
#  97,
#  114,
#  119,
#  105,
#  110,
#  32,
#  116,
#  101,
#  114,
#  195,
#  259,
#  161,
#  32,
#  112,
#  114,
#  111,
#  100,
#  117,
#  122,
#  105,
#  100,
#  257,
#  110,
#  257,
#  112,
#  101,
#  110,
#  115,
#  97,
#  109,
#  101,
#  110,
#  116,
#  257,
#  102,
#  105,
#  108,
#  111,
#  115,
#  195,
#  259,
#  179,
#  102,
#  105,
#  99,
#  257,
#  111,
#  99,
#  105,
#  100,
#  101,
#  110,
#  116,
#  97,
#  108,
#  46,
#  32,
#  83,
#  101,
#  103,
#  117,
#  110,
#  100,
#  257,
#  257,
#  97,
#  117,
#  116,
#  111,
#  114,
#  44,
#  32,
#  258,
#  116,
#  101,
#  111,
#  114,
#  105,
#  258,
#  100,
#  256,
#  68,
#  97,
#  114,
#  119,
#  105,
#  110,
#  32,
#  115,
#  117,
#  103,
#  101,
#  114,
#  256,
#  113,
#  117,
#  256,
#  258,
#  118,
#  105,
#  100,
#  258,
#  110,
#  257,
#  112,
#  108,
#  97,
#  110,
#  101,
#  116,
#  258,
#  84,
#  101,
#  114,
#  114,
#  258,
#  102,
#  111,
#  105,
#  32,
#  112,
#  114,
#  111,
#  100,
#  117,
#  122,
#  105,
#  100,
#  258,
#  112,
#  111,
#  114,
#  32,
#  117,
#  109,
#  32,
#  112,
#  114,
#  111,
#  99,
#  101,
#  115,
#  115,
#  257,
#  97,
#  108,
#  103,
#  111,
#  114,
#  195,
#  259,
#  173,
#  116,
#  109,
#  105,
#  99,
#  257,
#  97,
#  98,
#  115,
#  111,
#  108,
#  117,
#  116,
#  97,
#  109,
#  101,
#  110,
#  116,
#  256,
#  99,
#  101,
#  103,
#  111,
#  44,
#  32,
#  101,
#  110,
#  113,
#  117,
#  97,
#  110,
#  116,
#  257,
#  112,
#  101,
#  110,
#  115,
#  97,
#  100,
#  111,
#  114,
#  101,
#  115,
#  32,
#  100,
#  258,
#  195,
#  259,
#  169,
#  112,
#  111,
#  99,
#  258,
#  100,
#  256,
#  68,
#  97,
#  114,
#  119,
#  105,
#  110,
#  32,
#  100,
#  101,
#  102,
#  101,
#  110,
#  100,
#  105,
#  97,
#  109,
#  32,
#  113,
#  117,
#  256,
#  115,
#  195,
#  259,
#  179,
#  32,
#  68,
#  101,
#  117,
#  115,
#  32,
#  112,
#  111,
#  100,
#  101,
#  114,
#  105,
#  258,
#  99,
#  114,
#  105,
#  97,
#  114,
#  32,
#  116,
#  111,
#  100,
#  97,
#  115,
#  32,
#  97,
#  115,
#  32,
#  99,
#  111,
#  105,
#  115,
#  97,
#  115,
#  32,
#  99,
#  111,
#  110,
#  99,
#  101,
#  98,
#  105,
#  100,
#  97,
#  115,
#  46,
#  32,
#  65,
#  116,
#  114,
#  97,
#  118,
#  195,
#  259,
#  169,
#  115,
#  32,
#  100,
#  258,
#  115,
#  101,
#  108,
#  101,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  257,
#  110,
#  97,
#  116,
#  117,
#  114,
#  97,
#  108,
#  44,
#  32,
#  258,
#  99,
#  111,
#  110,
#  99,
#  101,
#  112,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  257,
#  256,
#  258,
#  112,
#  114,
#  195,
#  259,
#  179,
#  112,
#  114,
#  105,
#  258,
#  110,
#  111,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  257,
#  100,
#  256,
#  68,
#  101,
#  117,
#  115,
#  32,
#  115,
#  101,
#  114,
#  105,
#  97,
#  109,
#  32,
#  99,
#  114,
#  105,
#  97,
#  100,
#  97,
#  115,
#  32,
#  258,
#  112,
#  97,
#  114,
#  116,
#  105,
#  114,
#  32,
#  100,
#  256,
#  99,
#  111,
#  105,
#  115,
#  97,
#  115,
#  32,
#  109,
#  97,
#  105,
#  115,
#  32,
#  115,
#  105,
#  109,
#  112,
#  108,
#  101,
#  115,
#  46,
#  32,
#  65,
#  116,
#  114,
#  97,
#  118,
#  195,
#  259,
#  169,
#  115,
#  32,
#  100,
#  258,
#  98,
#  105,
#  111,
#  108,
#  111,
#  103,
#  105,
#  97,
#  44,
#  32,
#  68,
#  97,
#  114,
#  119,
#  105,
#  110,
#  32,
#  116,
#  101,
#  114,
#  105,
#  258,
#  101,
#  110,
#  99,
#  111,
#  110,
#  116,
#  114,
#  97,
#  100,
#  257,
#  117,
#  109,
#  258,
#  115,
#  111,
#  108,
#  117,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  257,
#  112,
#  97,
#  114,
#  258,
#  117,
#  109,
#  32,
#  112,
#  114,
#  111,
#  98,
#  108,
#  101,
#  109,
#  258,
#  100,
#  256,
#  102,
#  105,
#  108,
#  111,
#  115,
#  111,
#  102,
#  105,
#  258,
#  97,
#  110,
#  116,
#  105,
#  103,
#  97,
#  58,
#  32,
#  97,
#  115,
#  32,
#  111,
#  114,
#  105,
#  103,
#  101,
#  110,
#  115,
#  32,
#  100,
#  258,
#  99,
#  111,
#  110,
#  99,
#  101,
#  112,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  111,
#  46,
#  32,
#  61,
#  61,
#  32,
#  71,
#  114,
#  117,
#  97,
#  115,
#  32,
#  256,
#  71,
#  97,
#  110,
#  99,
#  104,
#  111,
#  115,
#  32,
#  67,
#  101,
#  108,
#  101,
#  115,
#  116,
#  101,
#  115,
#  32,
#  61,
#  61,
#  32,
#  68,
#  101,
#  110,
#  110,
#  101,
#  116,
#  116,
#  32,
#  105,
#  110,
#  116,
#  114,
#  111,
#  100,
#  117,
#  122,
#  32,
#  116,
#  101,
#  114,
#  109,
#  111,
#  115,
#  32,
#  99,
#  111,
#  109,
#  257,
#  34,
#  103,
#  114,
#  117,
#  97,
#  115,
#  34,
#  32,
#  40,
#  109,
#  101,
#  99,
#  97,
#  110,
#  105,
#  115,
#  109,
#  111,
#  115,
#  32,
#  113,
#  117,
#  256,
#  112,
#  114,
#  111,
#  100,
#  117,
#  122,
#  101,
#  109,
#  32,
#  99,
#  111,
#  110,
#  99,
#  101,
#  112,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  257,
#  100,
#  256,
#  98,
#  97,
#  105,
#  120,
#  257,
#  112,
#  97,
#  114,
#  258,
#  99,
#  105,
#  109,
#  258,
#  115,
#  101,
#  109,
#  32,
#  258,
#  110,
#  101,
#  99,
#  101,
#  115,
#  115,
#  105,
#  100,
#  97,
#  100,
#  256,
#  100,
#  256,
#  117,
#  109,
#  258,
#  101,
#  110,
#  116,
#  105,
#  100,
#  97,
#  100,
#  256,
#  115,
#  117,
#  112,
#  101,
#  114,
#  105,
#  111,
#  114,
#  41,
#  32,
#  256,
#  34,
#  71,
#  97,
#  110,
#  99,
#  104,
#  111,
#  115,
#  32,
#  67,
#  101,
#  108,
#  101,
#  115,
#  116,
#  101,
#  115,
#  34,
#  32,
#  40,
#  109,
#  101,
#  99,
#  97,
#  110,
#  105,
#  115,
#  109,
#  111,
#  115,
#  32,
#  113,
#  117,
#  256,
#  99,
#  114,
#  105,
#  97,
#  109,
#  32,
#  99,
#  111,
#  110,
#  99,
#  101,
#  112,
#  195,
#  259,
#  167,
#  195,
#  259,
#  163,
#  257,
#  112,
#  111,
#  114,
#  32,
#  109,
#  101,
#  105,
#  111,
#  115,
#  32,
#  109,
#  105,
#  108,
#  97,
#  103,
#  114,
#  111,
#  115,
#  111,
#  115,
#  41,
#  44,
#  32,
#  99,
#  111,
#  108,
#  111,
#  99,
#  97,
#  110,
#  100,
#  111,
#  45,
#  111,
#  115,
#  32,
#  99,
#  111,
#  109,
#  32,
#  117,
#  109,
#  32,
#  112,
#  97,
#  ...]

# %%
decoded_ids = tknF.decode(lul, vocab)
decoded_ids
# Out:
# 'A Ideia Perigosa de Darwin (em Portugal) ou A Perigosa Ideia de Darwin (no Brasil), Darwin\'s Dangerous Idea no original em inglÃªs, Ã© um livro da autoria de Daniel C. Dennett (1995) que explora os efeitos que a teoria da evoluÃ§Ã£o de Charles Darwin terÃ¡ produzido no pensamento filosÃ³fico ocidental. Segundo o autor, a teoria de Darwin sugere que a vida no planeta Terra foi produzida por um processo algorÃ\xadtmico absolutamente cego, enquanto pensadores da Ã©poca de Darwin defendiam que sÃ³ Deus poderia criar todas as coisas concebidas. AtravÃ©s da seleÃ§Ã£o natural, a concepÃ§Ã£o e a prÃ³pria noÃ§Ã£o de Deus seriam criadas a partir de coisas mais simples. AtravÃ©s da biologia, Darwin teria encontrado uma soluÃ§Ã£o para um problema de filosofia antiga: as origens da concepÃ§Ã£o. == Gruas e Ganchos Celestes == Dennett introduz termos como "gruas" (mecanismos que produzem concepÃ§Ã£o de baixo para cima sem a necessidade de uma entidade superior) e "Ganchos Celestes" (mecanismos que criam concepÃ§Ã£o por meios milagrosos), colocando-os com um papel preponderante de entre os possÃ\xadveis mecanismos susceptÃ\xadveis de criar concepÃ§Ã£o. Defende tambÃ©m a ideia de que Darwin conseguiu encontrar um processo de concepÃ§Ã£o que dispensa a existÃªncia de uma inteligÃªncia superior, baseado na ideia de seleÃ§Ã£o natural. == Adaptacionismo == Um dos temas discutidos no livro Ã© o adaptacionismo. O autor procura mostrar que os tÃ\xadmpanos de Stephen Jay Gould na realidade nÃ£o existem e sÃ£o de facto exaptaÃ§Ãµes. Dennett concede que Stephen Jay Gould chamou a atenÃ§Ã£o para alguns problemas importantes como o pan-adaptacionismo, mas defende que os darwinistas clÃ¡ssicos nunca foram adaptacionistas e que sempre tomaram em consideraÃ§Ã£o outros factores. Dennett mostra que Stephen Jay Gould nÃ£o refutou o adaptacionismo. Pelo contrÃ¡rio, deu-lhe mais consistÃªncia. == CrÃ\xadticas == Fundamentalismo darwiniano ou fundamentalismo darwinista Ã© o tÃ\xadtulo de um artigo de Stephen Jay Gould, no qual ele faz uma Ã¡vida crÃ\xadtica contra Daniel Dennett e Richard Dawkins, colocando-os como extremistas, ou "ultra-darwinistas". Ele critica o livro de Dennett como "o manifesto filosÃ³fico dos ultras do puro adaptacionismo". Ele afirma que este livro Ã© lido como a caricatura da caricatura. :se Richard Dawkins trivializou a riqueza de Darwin ao aderir para a mais estrita forma de argumento adaptacionista num modo maximamente reducionista, entÃ£o Dennet, como divulgador de Dawkins, consegue converter um imperfeito e improvÃ¡vel relato em numa doutrina ainda mais simplista e inflexÃ\xadvel. Se a histÃ³ria, como muitas vezes se nota, refaz grandiosidades em parÃ³dias, e se T. H. Huxley de fato agiu como o "buldogue de Darwin", entÃ£o Ã© difÃ\xadcil resistir de pensar em Dennet, no seu livro, como "cachorrinho de madame de Dawkins" A descriÃ§Ã£o de fundamentalismo darwiniano Ã© tambÃ©m utilizada por criacionistas para descrever qualquer cientista que defenda a evoluÃ§Ã£o de modo a fazer passar a ideia de que esses cientistas manifestam as mesmas caracterÃ\xadsticas dos fundamentalistas religiosos, como intolerÃ¢ncia, obscurantismo e dogmatismo. Categoria:Livros de biologia Categoria:Criacionismo Categoria:EvoluÃ§Ã�'
