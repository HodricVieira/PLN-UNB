# %%
for i in range(10):
    if i == 3:
        i = 7
    print(i)
# Out:
# 0
# 1
# 2
# 7
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# Suponha que temos uma lista
lista = [1, 2, 3, 4, 5]
dicio = {1 : [3,6,5], 2:[34,56,78]}

# Verificando se o número 3 está na lista
if 3 in dicio[2]:
    print("O número 3 está na lista.")
else:
    print("O número 3 não está na lista.")
# Out:
# O número 3 não está na lista.
